# %%
import pandas as pd
import seaborn as sns
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df = pd.read_csv('C:/부동산/data/finaldata_전처리.csv')

# %%
df
# Out:
#               계약년월일     전용면적    거래금액   층  건축년도        면적당가격    구     동   계약년  \
# 0        2007-01-01   59.970   21100   8  2006   351.842588  강동구    길동  2007
# 1        2007-01-01   59.340   22000   8  1996   370.744860  노원구   중계동  2007
# 2        2007-01-01   84.990   31500  10  2000   370.631839  성북구   정릉동  2007
# 3        2007-01-01   59.940   15800   9  1995   263.596930  노원구   월계동  2007
# 4        2007-01-01   84.570   28000   7  2003   331.086674  강동구    길동  2007
# ...             ...      ...     ...  ..   ...          ...  ...   ...   ...
# 1117745  2023-01-31   84.770  119000   4  1997  1403.798514  양천구    목동  2023
# 1117746  2023-01-31   59.855   57000  13  2003   952.301395  성북구  하월곡동  2023
# 1117747  2023-01-31   59.785  104500   7  2019  1747.930083  강동구   고덕동  2023
# 1117748  2023-01-31   14.910   12000  20  2014   804.828974  구로구   구로동  2023
# 1117749  2023-01-31  120.420  252000   1  1988  2092.675635  송파구   방이동  2023
#
#          계약월  ...       유로  소비자물가지수 소비자물가지수증감률  KOSPI_종가  KOSDAQ_종가  무담보콜금리  \
# 0          1  ...  1220.07   76.496        0.2   1360.23     576.37   4.630
# 1          1  ...  1220.07   76.496        0.2   1360.23     576.37   4.630
# 2          1  ...  1220.07   76.496        0.2   1360.23     576.37   4.630
# 3          1  ...  1220.07   76.496        0.2   1360.23     576.37   4.630
# 4          1  ...  1220.07   76.496        0.2   1360.23     576.37   4.630
# ...      ...  ...      ...      ...        ...       ...        ...     ...
# 1117745    1  ...  1332.83  110.100        0.8   2425.08     740.49   3.269
# 1117746    1  ...  1332.83  110.100        0.8   2425.08     740.49   3.269
# 1117747    1  ...  1332.83  110.100        0.8   2425.08     740.49   3.269
# 1117748    1  ...  1332.83  110.100        0.8   2425.08     740.49   3.269
# 1117749    1  ...  1332.83  110.100        0.8   2425.08     740.49   3.269
#
#          KORIBOR    CD  국고채_1년  국고채_10년
# 0           4.91  4.92   4.980    5.040
# 1           4.91  4.92   4.980    5.040
# 2           4.91  4.92   4.980    5.040
# 3           4.91  4.92   4.980    5.040
# 4           4.91  4.92   4.980    5.040
# ...          ...   ...     ...      ...
# 1117745     3.74  3.80   3.584    3.411
# 1117746     3.74  3.80   3.584    3.411
# 1117747     3.74  3.80   3.584    3.411
# 1117748     3.74  3.80   3.584    3.411
# 1117749     3.74  3.80   3.584    3.411
#
# [1117750 rows x 26 columns]

# %%
# 한글 처리를 위해 폰트 설정
font_name = font_manager.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family = font_name)

# %%
df_강남 = df[df['구'] == '강남구']

# %%
df_강남X = df_강남[['전용면적', '층', '건축년도', '계약년', '계약월',
       '주택담보대출', '미국달러', '일본엔', '유로', '소비자물가지수',
       'KOSPI_종가', 'KOSDAQ_종가', '무담보콜금리', 'KORIBOR', 'CD',
       '국고채_1년', '국고채_10년']]

# %%
df_상도동 = df[df['동'] == '상도동']

# %%
df_상도동X = df_상도동[['전용면적', '층', '건축년도', '계약년', '계약월',
       '주택담보대출', '미국달러', '일본엔', '유로', '소비자물가지수',
       'KOSPI_종가', 'KOSDAQ_종가', '무담보콜금리', 'KORIBOR', 'CD',
       '국고채_1년', '국고채_10년']]

# %%
df_강남X.corr()
# Out:
#                전용면적         층      건축년도       계약년       계약월    주택담보대출  \
# 전용면적       1.000000  0.184716  0.062368  0.114073  0.021402 -0.111776
# 층          0.184716  1.000000  0.271836  0.068352  0.006438 -0.047467
# 건축년도       0.062368  0.271836  1.000000  0.161270  0.036921 -0.122188
# 계약년        0.114073  0.068352  0.161270  1.000000  0.027498 -0.880142
# 계약월        0.021402  0.006438  0.036921  0.027498  1.000000 -0.085758
# 주택담보대출    -0.111776 -0.047467 -0.122188 -0.880142 -0.085758  1.000000
# 미국달러       0.016234  0.012136 -0.018823  0.103828 -0.047449 -0.077537
# 일본엔       -0.031443 -0.018855 -0.100270 -0.374932  0.002810  0.351323
# 유로        -0.066745 -0.028797 -0.117771 -0.639583 -0.050852  0.682041
# 소비자물가지수    0.115768  0.062542  0.149327  0.971382  0.079139 -0.890102
# KOSPI_종가   0.082881  0.056346  0.143165  0.766749  0.101421 -0.605728
# KOSDAQ_종가  0.063603  0.053427  0.143086  0.672217  0.024684 -0.481489
# 무담보콜금리    -0.104153 -0.047818 -0.103431 -0.769384 -0.070931  0.812175
# KORIBOR   -0.109495 -0.048832 -0.111304 -0.819181 -0.066925  0.892758
# CD        -0.110432 -0.049349 -0.111726 -0.817781 -0.074973  0.886860
# 국고채_1년    -0.112474 -0.050155 -0.112312 -0.850250 -0.047579  0.926427
# 국고채_10년   -0.109401 -0.048397 -0.128683 -0.893990 -0.081804  0.957402
#
#                미국달러       일본엔        유로   소비자물가지수  KOSPI_종가  KOSDAQ_종가  \
# 전용면적       0.016234 -0.031443 -0.066745  0.115768  0.082881   0.063603
# 층          0.012136 -0.018855 -0.028797  0.062542  0.056346   0.053427
# 건축년도      -0.018823 -0.100270 -0.117771  0.149327  0.143165   0.143086
# 계약년        0.103828 -0.374932 -0.639583  0.971382  0.766749   0.672217
# 계약월       -0.047449  0.002810 -0.050852  0.079139  0.101421   0.024684
# 주택담보대출    -0.077537  0.351323  0.682041 -0.890102 -0.605728  -0.481489
# 미국달러       1.000000  0.583190  0.484168  0.094705 -0.301701  -0.252452
# 일본엔        0.583190  1.000000  0.757483 -0.308179 -0.424446  -0.614230
# 유로         0.484168  0.757483  1.000000 -0.619578 -0.604964  -0.615506
# 소비자물가지수    0.094705 -0.308179 -0.619578  1.000000  0.759607   0.563934
# KOSPI_종가  -0.301701 -0.424446 -0.604964  0.759607  1.000000   0.794844
# KOSDAQ_종가 -0.252452 -0.614230 -0.615506  0.563934  0.794844   1.000000
# 무담보콜금리    -0.447777  0.047184  0.310184 -0.745386 -0.485654  -0.414394
# KORIBOR   -0.349369  0.136099  0.425087 -0.805550 -0.543637  -0.455435
# CD        -0.350263  0.131332  0.417906 -0.803865 -0.549339  -0.458770
# 국고채_1년    -0.343830  0.152802  0.466445 -0.835227 -0.540598  -0.449214
# 국고채_10년   -0.035830  0.381531  0.745918 -0.884762 -0.609594  -0.532580
#
#              무담보콜금리   KORIBOR        CD    국고채_1년   국고채_10년
# 전용면적      -0.104153 -0.109495 -0.110432 -0.112474 -0.109401
# 층         -0.047818 -0.048832 -0.049349 -0.050155 -0.048397
# 건축년도      -0.103431 -0.111304 -0.111726 -0.112312 -0.128683
# 계약년       -0.769384 -0.819181 -0.817781 -0.850250 -0.893990
# 계약월       -0.070931 -0.066925 -0.074973 -0.047579 -0.081804
# 주택담보대출     0.812175  0.892758  0.886860  0.926427  0.957402
# 미국달러      -0.447777 -0.349369 -0.350263 -0.343830 -0.035830
# 일본엔        0.047184  0.136099  0.131332  0.152802  0.381531
# 유로         0.310184  0.425087  0.417906  0.466445  0.745918
# 소비자물가지수   -0.745386 -0.805550 -0.803865 -0.835227 -0.884762
# KOSPI_종가  -0.485654 -0.543637 -0.549339 -0.540598 -0.609594
# KOSDAQ_종가 -0.414394 -0.455435 -0.458770 -0.449214 -0.532580
# 무담보콜금리     1.000000  0.983574  0.985325  0.958047  0.735153
# KORIBOR    0.983574  1.000000  0.999337  0.984659  0.819884
# CD         0.985325  0.999337  1.000000  0.982507  0.812626
# 국고채_1년     0.958047  0.984659  0.982507  1.000000  0.878542
# 국고채_10년    0.735153  0.819884  0.812626  0.878542  1.000000

# %%
df.columns
# Out:
# Index(['계약년월일', '전용면적', '거래금액', '층', '건축년도', '면적당가격', '구', '동', '계약년', '계약월',
#        '계약일', '년월', '일자', '주택담보대출', '미국달러', '일본엔', '유로', '소비자물가지수',
#        '소비자물가지수증감률', 'KOSPI_종가', 'KOSDAQ_종가', '무담보콜금리', 'KORIBOR', 'CD',
#        '국고채_1년', '국고채_10년'],
#       dtype='object')

# %%
dfX = df[['전용면적', '층', '건축년도', '계약년', '계약월',
       '주택담보대출', '미국달러', '일본엔', '유로', '소비자물가지수',
       'KOSPI_종가', 'KOSDAQ_종가', '무담보콜금리', 'KORIBOR', 'CD',
       '국고채_1년', '국고채_10년']]
dfy = df['면적당가격']

# %%
import statsmodels.api as sm
model = sm.OLS(dfy, dfX)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  면적당가격   R-squared (uncentered):                   0.805
# Model:                            OLS   Adj. R-squared (uncentered):              0.805
# Method:                 Least Squares   F-statistic:                          2.716e+05
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        16:46:49   Log-Likelihood:                     -8.2186e+06
# No. Observations:             1117750   AIC:                                  1.644e+07
# Df Residuals:                 1117733   BIC:                                  1.644e+07
# Df Model:                          17
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 전용면적           0.4169      0.012     34.076      0.000       0.393       0.441
# 층              7.1531      0.061    116.942      0.000       7.033       7.273
# 건축년도          -2.8416      0.040    -71.787      0.000      -2.919      -2.764
# 계약년            1.4230      0.040     35.167      0.000       1.344       1.502
# 계약월            4.5677      0.120     38.175      0.000       4.333       4.802
# 주택담보대출       -16.2201      2.043     -7.938      0.000     -20.225     -12.215
# 미국달러           0.4166      0.011     39.397      0.000       0.396       0.437
# 일본엔            4.0709      0.452      9.001      0.000       3.184       4.957
# 유로             0.4711      0.007     69.607      0.000       0.458       0.484
# 소비자물가지수       15.7092      0.217     72.354      0.000      15.284      16.135
# KOSPI_종가       0.1190      0.003     35.913      0.000       0.113       0.126
# KOSDAQ_종가      0.9063      0.006    140.002      0.000       0.894       0.919
# 무담보콜금리      -351.8827      3.938    -89.363      0.000    -359.600    -344.165
# KORIBOR      442.6011     10.416     42.492      0.000     422.186     463.016
# CD            53.4213     10.237      5.219      0.000      33.358      73.485
# 국고채_1년      -124.3806      4.029    -30.869      0.000    -132.278    -116.483
# 국고채_10년      -34.3710      1.759    -19.541      0.000     -37.818     -30.924
# ==============================================================================
# Omnibus:                   570708.181   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5469432.321
# Skew:                           2.269   Prob(JB):                         0.00
# Kurtosis:                      12.841   Cond. No.                     1.59e+05
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.59e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
dfX = df[['전용면적', '층', '건축년도', '계약년', '계약월',
       '주택담보대출', '미국달러', '일본엔', '유로', '소비자물가지수',
       'KOSPI_종가', 'KOSDAQ_종가']]
dfy = df['면적당가격']
model = sm.OLS(dfy, dfX)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  면적당가격   R-squared (uncentered):                   0.802
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                          3.785e+05
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        16:46:52   Log-Likelihood:                     -8.2260e+06
# No. Observations:             1117750   AIC:                                  1.645e+07
# Df Residuals:                 1117738   BIC:                                  1.645e+07
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 전용면적           0.4102      0.012     33.325      0.000       0.386       0.434
# 층              7.1709      0.062    116.466      0.000       7.050       7.292
# 건축년도          -2.9457      0.040    -73.989      0.000      -3.024      -2.868
# 계약년            1.1768      0.041     28.967      0.000       1.097       1.256
# 계약월            5.4390      0.109     49.717      0.000       5.225       5.653
# 주택담보대출        35.1455      0.772     45.539      0.000      33.633      36.658
# 미국달러           0.6356      0.009     74.648      0.000       0.619       0.652
# 일본엔            8.2755      0.415     19.955      0.000       7.463       9.088
# 유로             0.3472      0.005     63.175      0.000       0.336       0.358
# 소비자물가지수       20.6438      0.187    110.316      0.000      20.277      21.011
# KOSPI_종가       0.0700      0.003     23.914      0.000       0.064       0.076
# KOSDAQ_종가      0.9644      0.006    164.858      0.000       0.953       0.976
# ==============================================================================
# Omnibus:                   568310.051   Durbin-Watson:                   1.735
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5377388.757
# Skew:                           2.261   Prob(JB):                         0.00
# Kurtosis:                      12.747   Cond. No.                     8.67e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 8.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
dfX = df[['전용면적', '층', '건축년도', '계약년', '계약월',
       '미국달러', '일본엔', '유로', '소비자물가지수',
       'KOSPI_종가', 'KOSDAQ_종가']]
dfy = df['면적당가격']
model = sm.OLS(dfy, dfX)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  면적당가격   R-squared (uncentered):                   0.802
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                          4.119e+05
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        16:46:55   Log-Likelihood:                     -8.2270e+06
# No. Observations:             1117750   AIC:                                  1.645e+07
# Df Residuals:                 1117739   BIC:                                  1.645e+07
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 전용면적           0.3908      0.012     31.737      0.000       0.367       0.415
# 층              7.1510      0.062    116.038      0.000       7.030       7.272
# 건축년도          -2.8612      0.040    -71.878      0.000      -2.939      -2.783
# 계약년            1.3550      0.040     33.479      0.000       1.276       1.434
# 계약월            5.0621      0.109     46.362      0.000       4.848       5.276
# 미국달러           0.5596      0.008     66.962      0.000       0.543       0.576
# 일본엔            6.9756      0.414     16.844      0.000       6.164       7.787
# 유로             0.4602      0.005     93.761      0.000       0.451       0.470
# 소비자물가지수       15.4913      0.149    103.835      0.000      15.199      15.784
# KOSPI_종가       0.0837      0.003     28.700      0.000       0.078       0.089
# KOSDAQ_종가      0.9766      0.006    166.959      0.000       0.965       0.988
# ==============================================================================
# Omnibus:                   570208.106   Durbin-Watson:                   1.732
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5421988.968
# Skew:                           2.269   Prob(JB):                         0.00
# Kurtosis:                      12.789   Cond. No.                     4.60e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 4.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
dfX = df[['전용면적', '층', '건축년도', '계약년', '계약월',
       '미국달러', '유로', '소비자물가지수',
       'KOSPI_종가', 'KOSDAQ_종가']]
dfy = df['면적당가격']
model = sm.OLS(dfy, dfX)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  면적당가격   R-squared (uncentered):                   0.802
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                          4.530e+05
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        16:46:57   Log-Likelihood:                     -8.2272e+06
# No. Observations:             1117750   AIC:                                  1.645e+07
# Df Residuals:                 1117740   BIC:                                  1.645e+07
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 전용면적           0.3929      0.012     31.907      0.000       0.369       0.417
# 층              7.1488      0.062    115.989      0.000       7.028       7.270
# 건축년도          -2.8673      0.040    -72.025      0.000      -2.945      -2.789
# 계약년            1.3526      0.040     33.417      0.000       1.273       1.432
# 계약월            5.0965      0.109     46.679      0.000       4.883       5.310
# 미국달러           0.6162      0.008     80.511      0.000       0.601       0.631
# 유로             0.4936      0.004    109.866      0.000       0.485       0.502
# 소비자물가지수       15.2742      0.149    102.751      0.000      14.983      15.566
# KOSPI_종가       0.1008      0.003     36.838      0.000       0.095       0.106
# KOSDAQ_종가      0.9265      0.005    183.892      0.000       0.917       0.936
# ==============================================================================
# Omnibus:                   569996.436   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5409474.459
# Skew:                           2.269   Prob(JB):                         0.00
# Kurtosis:                      12.775   Cond. No.                     1.65e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
dfX = df[['전용면적', '층', '건축년도', '계약년', '계약월',
       '미국달러', '유로', '소비자물가지수', 'KOSDAQ_종가']]
dfy = df['면적당가격']
model = sm.OLS(dfy, dfX)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  면적당가격   R-squared (uncentered):                   0.802
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                          5.025e+05
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        16:46:59   Log-Likelihood:                     -8.2279e+06
# No. Observations:             1117750   AIC:                                  1.646e+07
# Df Residuals:                 1117741   BIC:                                  1.646e+07
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 전용면적           0.3936      0.012     31.947      0.000       0.369       0.418
# 층              7.1491      0.062    115.923      0.000       7.028       7.270
# 건축년도          -2.8484      0.040    -71.511      0.000      -2.926      -2.770
# 계약년            1.2304      0.040     30.482      0.000       1.151       1.310
# 계약월            5.3692      0.109     49.261      0.000       5.156       5.583
# 미국달러           0.4451      0.006     73.125      0.000       0.433       0.457
# 유로             0.5771      0.004    148.684      0.000       0.569       0.585
# 소비자물가지수       19.5748      0.092    212.586      0.000      19.394      19.755
# KOSDAQ_종가      1.0620      0.003    308.172      0.000       1.055       1.069
# ==============================================================================
# Omnibus:                   569440.077   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5410245.894
# Skew:                           2.266   Prob(JB):                         0.00
# Kurtosis:                      12.779   Cond. No.                     1.04e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
dfX = df[['전용면적', '층', '건축년도', '계약월',
       '미국달러', '유로', '소비자물가지수', 'KOSDAQ_종가']]
dfy = df['면적당가격']
model = sm.OLS(dfy, dfX)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  면적당가격   R-squared (uncentered):                   0.802
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                          5.648e+05
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        16:47:01   Log-Likelihood:                     -8.2283e+06
# No. Observations:             1117750   AIC:                                  1.646e+07
# Df Residuals:                 1117742   BIC:                                  1.646e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 전용면적           0.3769      0.012     30.610      0.000       0.353       0.401
# 층              6.8242      0.061    112.299      0.000       6.705       6.943
# 건축년도          -1.6424      0.005   -356.533      0.000      -1.651      -1.633
# 계약월            5.2805      0.109     48.444      0.000       5.067       5.494
# 미국달러           0.4503      0.006     73.980      0.000       0.438       0.462
# 유로             0.5833      0.004    150.427      0.000       0.576       0.591
# 소비자물가지수       20.1614      0.090    223.809      0.000      19.985      20.338
# KOSDAQ_종가      1.0677      0.003    310.177      0.000       1.061       1.074
# ==============================================================================
# Omnibus:                   572570.434   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5456260.667
# Skew:                           2.281   Prob(JB):                         0.00
# Kurtosis:                      12.816   Cond. No.                         841.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
dfX = df[['전용면적', '층', '건축년도', '계약월',
       '미국달러', '유로', 'KOSDAQ_종가']]
dfy = df['면적당가격']
model = sm.OLS(dfy, dfX)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  면적당가격   R-squared (uncentered):                   0.793
# Model:                            OLS   Adj. R-squared (uncentered):              0.793
# Method:                 Least Squares   F-statistic:                          6.109e+05
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        16:47:03   Log-Likelihood:                     -8.2528e+06
# No. Observations:             1117750   AIC:                                  1.651e+07
# Df Residuals:                 1117743   BIC:                                  1.651e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 전용면적           0.4371      0.013     34.734      0.000       0.412       0.462
# 층              6.9810      0.062    112.395      0.000       6.859       7.103
# 건축년도          -0.9373      0.003   -272.839      0.000      -0.944      -0.931
# 계약월            7.2658      0.111     65.429      0.000       7.048       7.483
# 미국달러           1.3657      0.005    296.397      0.000       1.357       1.375
# 유로             0.0470      0.003     15.094      0.000       0.041       0.053
# KOSDAQ_종가      1.3314      0.003    402.700      0.000       1.325       1.338
# ==============================================================================
# Omnibus:                   567300.482   Durbin-Watson:                   1.657
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5251207.244
# Skew:                           2.265   Prob(JB):                         0.00
# Kurtosis:                      12.604   Cond. No.                         832.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
dfX = df[['전용면적', '층', '건축년도', '계약월',
       '미국달러', '유로', '소비자물가지수', 'KOSDAQ_종가']]
dfy = df['면적당가격']
model.fit(dfX, dfy)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dfX, dfy, test_size=0.3, random_state=10)
model = LinearRegression().fit(X_train, y_train)

print("학습용 : ", model.score(X_train, y_train))
print("검증용 : ", model.score(X_test, y_test))
# Out:
# 학습용 :  0.24391409124528607
# 검증용 :  0.24257790655271472

# %%
model.predict([[100, 10, 1987, 3, 1400, 1500, 120, 700]])
# Out:
# c:\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1536.80021703])
